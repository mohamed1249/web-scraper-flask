# %%
links = ['https://www.ggdwb.nl/veelgestelde-vragen/',
         'https://groeigids.nl/baby',
         'https://groeigids.nl/peuter',
         'https://www.thuisarts.nl/aardbeivlek',
         'https://www.thuisarts.nl/adhd',
         'https://www.thuisarts.nl/angst-bij-kinderen',
         'https://www.thuisarts.nl/antibiotica',
         'https://www.thuisarts.nl/astma-bij-kinderen',
         'https://www.thuisarts.nl/autisme',
         'https://www.thuisarts.nl/baby-zat-tijdens-bevalling-vast-met-schouder',
         'https://www.thuisarts.nl/babys-en-huilen',
         'https://www.thuisarts.nl/bedplassen-bij-kinderen',
         'https://www.thuisarts.nl/berg',
         'https://www.thuisarts.nl/blaasontsteking-bij-kinderen',
         'https://www.thuisarts.nl/blindedarmontsteking/ik-denk-dat-mijn-kind-blindedarmontsteking-heeft',
         'https://www.thuisarts.nl/bof',
         'https://www.thuisarts.nl/borstontsteking-bij-borstvoeding',
         'https://www.thuisarts.nl/borstvoeding',
         'https://www.thuisarts.nl/brandwonden',
         'https://www.thuisarts.nl/buikgriep',
         'https://www.thuisarts.nl/buikpijn-bij-kinderen',
         'https://www.thuisarts.nl/coeliakie',
         'https://www.thuisarts.nl/delier-bij-kinderen',
         'https://www.thuisarts.nl/depressie-na-bevalling',
         'https://www.thuisarts.nl/diarree',
         'https://www.thuisarts.nl/downsyndroom',
         'https://www.thuisarts.nl/droge-huid',
         'https://www.thuisarts.nl/eczeem',
         'https://www.thuisarts.nl/eetstoornis/heeft-mijn-kind-eetprobleem',
         'https://www.thuisarts.nl/epilepsie',
         'https://www.thuisarts.nl/eten-zit-vast-in-keel-of-slokdarm-kind',
         'https://www.thuisarts.nl/flauwvallen',
         'https://www.thuisarts.nl/geelzucht-baby',
         'https://www.thuisarts.nl/gestoken-door-insect',
         'https://www.thuisarts.nl/kruis-allergie',
         'https://www.thuisarts.nl/gezond-eten',
         'https://www.thuisarts.nl/gezond-leven/krijgt-mijn-kind-genoeg-vitamines-binnen',
         'https://www.thuisarts.nl/griep',
         'https://www.thuisarts.nl/groei-kind',
         'https://www.thuisarts.nl/hand-voet-mondziekte',
         'https://www.thuisarts.nl/hersenvlies-ontsteking',
         'https://www.thuisarts.nl/heupdysplasie',
         'https://www.thuisarts.nl/heupontsteking-bij-kinderen',
         'https://www.thuisarts.nl/hik',
         'https://www.thuisarts.nl/hooikoorts',
         'https://www.thuisarts.nl/jeuk',
         'https://www.thuisarts.nl/keelpijn',
         'https://www.thuisarts.nl/kind-stopt-even-met-ademen',
         'https://www.thuisarts.nl/kind-weegt-te-weinig',
         'https://www.thuisarts.nl/kindermishandeling-0',
         'https://www.thuisarts.nl/kinderziekten-met-vlekjes',
         'https://www.thuisarts.nl/kinkhoest',
         'https://www.thuisarts.nl/klompvoet-bij-baby/mijn-baby-is-geboren-met-klompvoet',
         'https://www.thuisarts.nl/koorts-bij-kinderen',
         'https://www.thuisarts.nl/koorts-na-prik-tegen-kinderziektes',
         'https://www.thuisarts.nl/koortsstuip',
         'https://www.thuisarts.nl/koortsstuip',
         'https://www.thuisarts.nl/lichen-sclerosus/mijn-kind-heeft-lichen-sclerosus',
         'https://www.thuisarts.nl/liesbreuk',
         'https://www.thuisarts.nl/longschade-bij-te-vroeg-geboren-baby',
         'https://www.thuisarts.nl/loopoor/mijn-kind-heeft-loopoor',
         'https://www.thuisarts.nl/lui-oog/mijn-kind-heeft-lui-oog',
         'https://www.thuisarts.nl/luieruitslag/mijn-kind-heeft-last-van-luieruitslag',
         'https://www.thuisarts.nl/luizen-op-hoofd/mijn-kind-heeft-luizen-op-hoofd',
        #  'https://www.thuisarts.nl/mazelen/mijn-kind-heeft-mazelen',
         '',
         'https://www.thuisarts.nl/minder-goed-zien-bij-kinderen',
         'https://www.thuisarts.nl/moedervlekken',
         'https://www.thuisarts.nl/o-en-x-benen-bij-kinderen/mijn-kind-heeft-o-benen-of-x-benen-is-dat-erg',
         'https://www.thuisarts.nl/oogafwijking-bij-te-vroeg-geboren-baby',
        #  'https://www.thuisarts.nl/oorpijn/mijn-kind-heeft-oorpijn',
        '',
        #  'https://www.thuisarts.nl/overgewicht-bij-kinderen',
        '',
         'https://www.thuisarts.nl/problemen-met-poepen-bij-kinderen',
         'https://www.thuisarts.nl/pseudokroep',
         'https://www.thuisarts.nl/rode-hond',
         'https://www.thuisarts.nl/roodvonk',
         'https://www.thuisarts.nl/rs-virus',
         'https://www.thuisarts.nl/vieze-oogjes-bij-babys/mijn-baby-heeft-vieze-oogjes',
         'https://www.thuisarts.nl/scheelzien-bij-kinderen',
         'https://www.thuisarts.nl/schisis',
         'https://www.thuisarts.nl/smetplekken',
         'https://www.thuisarts.nl/spruw/mijn-baby-heeft-spruw',
         'https://www.thuisarts.nl/spugen-bij-babys/mijn-baby-spuugt-veel-reflux',
         'https://www.thuisarts.nl/trommelvliesbuisjes/mijn-kind-krijgt-trommelvliesbuisjes',
         'https://www.thuisarts.nl/vijfde-ziekte',
         'https://www.thuisarts.nl/voorwerp-inslikken',
         'https://www.thuisarts.nl/waterpokken',
         'https://www.thuisarts.nl/waterwratjes',
         'https://www.thuisarts.nl/wonden',
         'https://www.thuisarts.nl/wormpjes',
         'https://www.thuisarts.nl/zesde-ziekte',
         'https://www.thuisarts.nl/ziek-kind']

len(links)
# Out:
# 91

# %%
import pandas as pd

df = pd.read_csv('GGD West Brabant ICH Master - Submission.csv').iloc[:,:5].dropna()
df
# Out:
#                               GGD Content Spider URL's PDF Download
# 0    https://www.ggdwb.nl/veelgestelde-vragen/   on...            N  \
# 1                            https://groeigids.nl/baby            N
# 2                          https://groeigids.nl/peuter            N
# 4                 https://www.thuisarts.nl/aardbeivlek            N
# 5                        https://www.thuisarts.nl/adhd            N
# ..                                                 ...          ...
# 142                        Waterwratjes | Thuisarts.nl            N
# 144                              Wonden | Thuisarts.nl            N
# 146                            Wormpjes | Thuisarts.nl            N
# 148                        Zesde ziekte | Thuisarts.nl            N
# 150                           Ziek kind | Thuisarts.nl            N
#
#     Download the content on the first page URL
# 0                                            N  \
# 1                                            N
# ...

# %%
df.shape
# Out:
# (91, 5)

# %%
df['GGD Content Spider URL\'s'] = links

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 150
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   GGD Content Spider URL's                    91 non-null     object
#  1   PDF Download                                91 non-null     object
#  2   Download the content on the first page URL  91 non-null     object
#  3   Follow the links on the page and download   91 non-null     object
#  4   Combine in 1 CSV with Main page URL         91 non-null     object
# dtypes: object(5)
# memory usage: 4.3+ KB

# %%
from scr_prp import *

# %%
urls = df['GGD Content Spider URL\'s']
download_pdfs = df['PDF Download']
download_content = df['Download the content on the first page URL']
download_sub_content = df['Follow the links on the page and download']
errors = []
num_scraped = {'main': 0, 'sub' : 0}

# List of directories to ensure existence
directories_to_create = ['JSONs' ,'PDFs']
link_dirs = [clean_title(link) for link in df['GGD Content Spider URL\'s']]

# %%
for directory in directories_to_create:
    if not os.path.exists(directory):
        os.makedirs(directory)

for directory in link_dirs:
    if not os.path.exists(os.path.join('sep JSONs',directory)):
        os.makedirs(os.path.join('sep JSONs',directory))

for i, url, dpdf, dc, dsc in zip(range(len(df)) ,urls, download_pdfs, download_content, download_sub_content):
    if f"{clean_title(url)}{dc.lower()}{dsc.lower()}.json" in os.listdir("JSONs"):
        print(f"{clean_title(url)}{dc.lower()}{dsc.lower()}.json already exists!")
        continue

    if dpdf.lower() != 'n':
        try:
            # Download PDFs from the page
            PDFs = download_pdfs_from_url(url)
        except Exception as e:
            PDFs = []
            error_message = f'Error downloading PDFs from {url}: {e}'
            print(error_message)
            errors.append(error_message)


    if dc.lower() != 'n' and dsc.lower() == 'n':
        print(f'{i+1} - Scraping {url}')
        # Scrape the content of the page and save it to a JSON file
        try:
            page_content = scrape_page_content(url)
            num_scraped['main'] += 1 
        except Exception as e:
            PDFs = []
            error_message = f'Error geting page contents from {url}: {e}'
            print(error_message)
            errors.append(error_message)
            page_content = False

        if page_content:
            PDFs = []
            cleaned_title = clean_title(url)
            json_filename = f"{cleaned_title}{dc.lower()}{dsc.lower()}.json"
            json_path = os.path.join("JSONs", json_filename)
            with open(json_path, "w", encoding="utf-8") as json_file:
                json.dump({"webpage_url": url, "content": page_content, 'attached_PDFs':PDFs}, json_file, ensure_ascii=False, indent=4)
            print(f"Scraped {url} and saved the content to {json_filename}")
            save_seprated(page_content, os.path.join('sep JSONs',cleaned_title))

    elif dc.lower() != 'n' and dsc.lower() != 'n':
        print(f'{i+1} - Scraping main&sub-links from {url}',end='')
        # Scrape the content of the page and save it to a JSON file
        try:
            page_content, num_sub = scrape_page_and_subpages_content(url)
            num_scraped['main'] += 1 
            num_scraped['sub'] += num_sub 

        except Exception as e:
            PDFs = []
            error_message = f'Error geting page contents from {url}: {e}'
            print(error_message)
            errors.append(error_message)
            page_content = False

        if page_content:
            PDFs = []
            cleaned_title = clean_title(url)
            json_filename = f"{cleaned_title}{dc.lower()}{dsc.lower()}.json"
            json_path = os.path.join("JSONs", json_filename)
            with open(json_path, "w", encoding="utf-8") as json_file:
                json.dump(page_content, json_file, ensure_ascii=False, indent=4)
            print(f"Scraped {url} and saved the content to {json_filename}")
            save_seprated(page_content, os.path.join('sep JSONs',cleaned_title))

    elif dc.lower() == 'n' and dsc.lower() != 'n':
        print(f'{i+1} - Scraping sub-links from {url}',end='')
        # Scrape the content of the page and save it to a JSON file
        try:
            page_content, num_sub = scrape_page_and_subpages_content(url, main_content = False)
            num_scraped['sub'] += num_sub 
        except Exception as e:
            PDFs = []
            error_message = f'Error geting page contents from {url}: {e}'
            print(error_message)
            errors.append(error_message)
            page_content = False

        if page_content:
            PDFs = []
            cleaned_title = clean_title(url)
            json_filename = f"{cleaned_title}{dc.lower()}{dsc.lower()}.json"
            json_path = os.path.join("JSONs", json_filename)
            with open(json_path, "w", encoding="utf-8") as json_file:
                json.dump(page_content, json_file, ensure_ascii=False, indent=4)
            print(f"Scraped {url} and saved the content to {json_filename}")
            save_seprated(page_content, os.path.join('sep JSONs',cleaned_title))


pdfs_directory = "PDFs"

for root, _, files in os.walk(pdfs_directory):
    for file in files:
        try:
            if file.endswith(".pdf"):
                pdf_file_path = os.path.join(root, file)
                pdf_pages_data = extract_pdf_pages(pdf_file_path)
                pdf_filename = os.path.splitext(file)[0]
                output_json_file_path = os.path.join("JSONs", f"{pdf_filename}_pages_data.json")
                with open(output_json_file_path, "w", encoding="utf-8") as output_json_file:
                    json.dump(pdf_pages_data, output_json_file, ensure_ascii=False, indent=4)
        except Exception as e:
            print(f"Couldn't process {file}: {e}")

print('Done!')
# Out:
# https___www.ggdwb.nl_veelgestelde-vragen_ny.json already exists!
# 2 - Scraping sub-links from https://groeigids.nl/baby (198 links)
# 	1 - Scraped sub-content from https://groeigids.nl
# 	2 - Scraped sub-content from https://groeigids.nl/baby/kleine-voorwerpen-inslikken/7223
# 	3 - Scraped sub-content from https://groeigids.nl/over-groeigids/privacy-statement
# 	4 - Scraped sub-content from https://groeigids.nl/baby/bloed-in-de-luier/7253
# 	5 - Scraped sub-content from https://groeigids.nl/baby/kruik/6677
# 	6 - Scraped sub-content from https://groeigids.nl/baby/televisie-en-beeldscherm/7386
# 	7 - Scraped sub-content from https://groeigids.nl/baby/koortslip/7298
# 	8 - Scraped sub-content from https://groeigids.nl/baby/flesvoeding-geven/7273
# 	9 - Scraped sub-content from https://groeigids.nl/baby/soorten-vaste-voeding/7235
# 	10 - Scraped sub-content from https://groeigids.nl/baby/twee-kinderen-aan-de-borst/6875
# ...

# %%
num_scraped
# Out:
# {'main': 0, 'sub': 0}

# %%
def scrape_baby_page_and_subpages_content(url='https://groeigids.nl/baby', main_content=False, timeout=30):
    """
    Scrapes the text content of a webpage and optionally its sub-links recursively.

    Args:
      url: The URL of the page to scrape.
      main_content: Boolean indicating whether to scrape the main content of the page.
      timeout: The maximum time to wait for a response in seconds (default: 10).

    Returns:
      A dictionary containing the combined text content of the page and its sub-links.
    """
    try:
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
    except requests.exceptions.RequestException as e:
        print(f"\tFailed to fetch {url}: {e}")
        return None

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract content from current page
        content = {}
        if main_content:
            content[url] = {'content': scrape_page_content(url), 'main_content': True}

        # Extract and recursively scrape sub-links
        sub_links = list({a['href'] for a in soup.find_all('a', href=True) if 'facebook' not in a['href']})
        print(f' ({len(sub_links)} links)')
        for i, sub_link in enumerate(sub_links):
            try:
                sub_content = scrape_page_content(sub_link)
                if sub_content:
                    content[sub_link] = {'content': sub_content, 'main_content': False}
                    print(f"\t{i+1} - Scraped sub-content from {sub_link}")
            except:
                sub_link = 'https://groeigids.nl' + sub_link
                sub_content = scrape_page_content(sub_link)
                if sub_content:
                    content[sub_link] = {'content': sub_content, 'main_content': False}
                    print(f"\t{i+1} - Scraped sub-content from {sub_link}")
        return content, len(sub_links)

    else:
        print(f"\tFailed to fetch {url}")
        return None
    
baby_content, num_links = scrape_baby_page_and_subpages_content()
# Out:
#  (198 links)
# 	1 - Scraped sub-content from https://groeigids.nl
# 	2 - Scraped sub-content from https://groeigids.nl/peuter
# 	3 - Scraped sub-content from https://groeigids.nl/baby/buikligging/6780
# 	4 - Scraped sub-content from https://groeigids.nl/baby/baby-in-bad/7764
# 	5 - Scraped sub-content from https://groeigids.nl/baby/verstandelijke-ontwikkeling/7550
# 	6 - Scraped sub-content from https://groeigids.nl/baby/flesvoeding-klaarmaken/6487
# 	7 - Scraped sub-content from https://groeigids.nl/baby/scheef-hoofdje/7091
# 	8 - Scraped sub-content from https://groeigids.nl/baby/te-vroeg-geboren/6945
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Input In [10], in scrape_baby_page_and_subpages_content(url, main_content, timeout)
#      32 try:
# ---> 33     sub_content = scrape_page_content(sub_link)
#      34     if sub_content:
#
# ...

# %%
for key, value in baby_content.items():
    sub_dict = {'URL':key, 'Content': value['content']}
    cleaned_title = clean_title(key)
    json_filename = f"{cleaned_title}.json"
    json_path = os.path.join("Babies", json_filename)
    with open(json_path, "w", encoding="utf-8") as json_file:
        json.dump(sub_dict, json_file, ensure_ascii=False, indent=4)

# %%
pd.Series(baby_content.keys()).to_csv('baby_links.csv')

# %%
with open('combined_babies.json', "w", encoding="utf-8") as json_file:
    json.dump(baby_content, json_file, ensure_ascii=False, indent=4)

# %%
def scrape_peuter_page_and_subpages_content(url='https://groeigids.nl/peuter', main_content=False, timeout=30):
    """
    Scrapes the text content of a webpage and optionally its sub-links recursively.

    Args:
      url: The URL of the page to scrape.
      main_content: Boolean indicating whether to scrape the main content of the page.
      timeout: The maximum time to wait for a response in seconds (default: 10).

    Returns:
      A dictionary containing the combined text content of the page and its sub-links.
    """
    try:
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
    except requests.exceptions.RequestException as e:
        print(f"\tFailed to fetch {url}: {e}")
        return None

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract content from current page
        content = {}
        if main_content:
            content[url] = {'content': scrape_page_content(url), 'main_content': True}

        # Extract and recursively scrape sub-links
        sub_links = list({a['href'] for a in soup.find_all('a', href=True) if 'facebook' not in a['href']})
        print(f' ({len(sub_links)} links)')
        for i, sub_link in enumerate(sub_links):
            try:
                sub_content = scrape_page_content(sub_link)
                if sub_content:
                    content[sub_link] = {'content': sub_content, 'main_content': False}
                    print(f"\t{i+1} - Scraped sub-content from {sub_link}")
            except:
                sub_link = 'https://groeigids.nl' + sub_link
                sub_content = scrape_page_content(sub_link)
                if sub_content:
                    content[sub_link] = {'content': sub_content, 'main_content': False}
                    print(f"\t{i+1} - Scraped sub-content from {sub_link}")
        return content, len(sub_links)

    else:
        print(f"\tFailed to fetch {url}")
        return None
    
peuter_content, num_links = scrape_peuter_page_and_subpages_content()
# Out:
#  (190 links)
# 	1 - Scraped sub-content from https://groeigids.nl
# 	2 - Scraped sub-content from https://groeigids.nl/peuter/gezonde-voeding-2/6216
# 	3 - Scraped sub-content from https://groeigids.nl/peuter/vaccinaties/8354
# 	4 - Scraped sub-content from https://groeigids.nl/peuter/stress/7740
# 	5 - Scraped sub-content from https://groeigids.nl/peuter/fantasie-en-werkelijkheid/6532
# 	6 - Scraped sub-content from https://groeigids.nl/peuter/druk-gedrag/6637
# 	7 - Scraped sub-content from https://groeigids.nl/peuter/oogtest/6217
# 	8 - Scraped sub-content from https://groeigids.nl/peuter/samenspelen/7207
# 	9 - Scraped sub-content from https://groeigids.nl/peuter/vroeg-wakker/6690
# 	10 - Scraped sub-content from https://groeigids.nl/peuter/groei-en-ontwikkeling/7800
# 	11 - Scraped sub-content from https://groeigids.nl/peuter/jeugdgezondheidszorg-2/7410
# 	12 - Scraped sub-content from https://groeigids.nl/peuter/media-op-het-kinderdagverblijf/6957
# ...

# %%
for key, value in peuter_content.items():
    sub_dict = {'URL':key, 'Content': value['content']}
    cleaned_title = clean_title(key)
    json_filename = f"{cleaned_title}.json"
    json_path = os.path.join("Peuters", json_filename)
    with open(json_path, "w", encoding="utf-8") as json_file:
        json.dump(sub_dict, json_file, ensure_ascii=False, indent=4)

# %%
pd.Series(peuter_content.keys()).to_csv('peuter_links.csv', header=False)

# %%
with open('combined_Peuters.json', "w", encoding="utf-8") as json_file:
    json.dump(peuter_content, json_file, ensure_ascii=False, indent=4)

# %%
print(f'Scraping sub-links from https://sayhaito.com/ggd-west-brabant-faq/',end='')
# Scrape the content of the page and save it to a JSON file
try:
    page_content, num_sub = scrape_page_and_subpages_content('https://sayhaito.com/ggd-west-brabant-faq/', main_content = False)
    num_scraped['sub'] += num_sub
except Exception as e:
    PDFs = []
    error_message = f'Error geting page contents from https://sayhaito.com/ggd-west-brabant-faq/: {e}'
    print(error_message)
    errors.append(error_message)
    page_content = False

if page_content:
    PDFs = []
    cleaned_title = clean_title('https://sayhaito.com/ggd-west-brabant-faq/')
    json_filename = f"{cleaned_title}{dc.lower()}{dsc.lower()}.json"
    json_path = os.path.join("JSONs", json_filename)
    with open(json_path, "w", encoding="utf-8") as json_file:
        json.dump(page_content, json_file, ensure_ascii=False, indent=4)
    print(f"Scraped https://sayhaito.com/ggd-west-brabant-faq/ and saved the content to {json_filename}")
    save_seprated(page_content, os.path.join('sep JSONs',cleaned_title))
# Out:
# Scraping sub-links from https://sayhaito.com/ggd-west-brabant-faq/	Failed to fetch https://sayhaito.com/ggd-west-brabant-faq/: 403 Client Error: Forbidden for url: https://sayhaito.com/ggd-west-brabant-faq/
# Error geting page contents from https://sayhaito.com/ggd-west-brabant-faq/: cannot unpack non-iterable NoneType object

# %%
from bs4 import BeautifulSoup

def scrape_urls(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find all <a> tags (anchor tags) and extract the 'href' attribute
    links = soup.find_all('a', href=True)
    
    # Extract and print the URLs
    for link in links:
        url = link['href']
        yield url

# Replace 'your_html_file.html' with the path to your HTML file
file_path = r"C:\Users\LAPTOP WORLD\Desktop\GGD West Brabant FAQ – AI Powered Innovation.html"

# Read the HTML file content
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Call the function to scrape URLs
for URL in scrape_urls(html_content):
    if 'google' in URL:
        URL = URL[URL.index('=')+1:URL.index('&')]
        try:
            content = scrape_page_content(URL)
            if content:
                sub_dict =  {'URL':URL, 'Content': scrape_page_content(URL)}
                cleaned_title = clean_title(URL)
                json_filename = f"{cleaned_title}.json"
                json_path = os.path.join("sh", json_filename)
                with open(json_path, "w", encoding="utf-8") as json_file:
                    json.dump(sub_dict, json_file, ensure_ascii=False, indent=4)
                print(f"Scraped {URL} and saved the content to {json_filename}")
            else: print(f'Failed to scrape {URL}')
        except:
            print(f'Failed to scrape {URL}')
# Out:
# Scraped https://www.ggdwb.nl/veel-gestelde-vragen/het-lukt-mij-niet-om-een-afspraak-te-maken/ and saved the content to https___www.ggdwb.nl_veel-gestelde-vragen_het-lukt-mij-niet-om-een-afspraak-te-maken_.json
# Scraped https://www.ggdwb.nl/veel-gestelde-vragen/ik-zie-geen-ruimte-in-de-agenda-om-een-afspraak-te-maken-hoe-kan-dat/ and saved the content to https___www.ggdwb.nl_veel-gestelde-vragen_ik-zie-geen-ruimte-in-de-agenda-om-een-afspraak-te-maken-hoe-kan-dat_.json
# Scraped https://www.ggdwb.nl/veel-gestelde-vragen/hoe-maak-ik-een-afspraak-voor-een-prenataal-huisbezoek-via-ouderportaal/ and saved the content to https___www.ggdwb.nl_veel-gestelde-vragen_hoe-maak-ik-een-afspraak-voor-een-prenataal-huisbezoek-via-ouderportaal_.json
# Scraped https://www.ggdwb.nl/veel-gestelde-vragen/hoe-zorg-je-voor-juiste-juridische-dossiervoering/ and saved the content to https___www.ggdwb.nl_veel-gestelde-vragen_hoe-zorg-je-voor-juiste-juridische-dossiervoering_.json
# ...

# %%
for directory in directories_to_create:
    if not os.path.exists(directory):
        os.makedirs(directory)

for directory in link_dirs:
    if not os.path.exists(os.path.join('sep JSONs',directory)):
        os.makedirs(os.path.join('sep JSONs',directory))

for i, url, dpdf, dc, dsc in zip(range(len(df)) ,urls, download_pdfs, download_content, download_sub_content):
    if 'thuisarts' not in url:
        print(f"{clean_title(url)}{dc.lower()}{dsc.lower()}.json already exists!")
        continue

    try:
        page_content = scrape_page_content(url)
    except Exception as e:
        PDFs = []
        error_message = f'Error geting page contents from {url}: {e}'
        print(error_message)
        errors.append(error_message)
        page_content = False

    if page_content:
        PDFs = []
        cleaned_title = clean_title(url)
        json_filename = f"{cleaned_title}{dc.lower()}{dsc.lower()}.json"
        json_path = os.path.join("thuisarts", json_filename)
        with open(json_path, "w", encoding="utf-8") as json_file:
            json.dump({"webpage_url": url, "content": page_content}, json_file, ensure_ascii=False, indent=4)
        print(f"Scraped {url} and saved the content to {json_filename}")
        # save_seprated(page_content, os.path.join('sep JSONs',cleaned_title))
# Out:
# https___www.ggdwb.nl_veelgestelde-vragen_ny.json already exists!
# https___groeigids.nl_babyny.json already exists!
# https___groeigids.nl_peuterny.json already exists!
# Scraped https://www.thuisarts.nl/aardbeivlek and saved the content to https___www.thuisarts.nl_aardbeivlekyy.json
# Scraped https://www.thuisarts.nl/adhd and saved the content to https___www.thuisarts.nl_adhdyy.json
# Scraped https://www.thuisarts.nl/angst-bij-kinderen and saved the content to https___www.thuisarts.nl_angst-bij-kinderenyy.json
# Scraped https://www.thuisarts.nl/antibiotica and saved the content to https___www.thuisarts.nl_antibioticayy.json
# Scraped https://www.thuisarts.nl/astma-bij-kinderen and saved the content to https___www.thuisarts.nl_astma-bij-kinderenyy.json
# Scraped https://www.thuisarts.nl/autisme and saved the content to https___www.thuisarts.nl_autismeyy.json
# ...

# %%
import os
import json
import pandas as pd

directories = ['Babies','Peuters','sh','thuisarts']
for d in directories:
    links = []
    for file in os.listdir(d):
        with open(os.path.join(d,file), "r", encoding="utf-8") as f:
            # Read the contents of the file
            data = f.read()
            data_dict = json.loads(data)
            try:
                links.append(data_dict['URL'])
            except: links.append(data_dict['webpage_url'])
    pd.Series(links).to_csv(f'{d}.csv', header=False)

# %%
data_dict
# Out:
# {'webpage_url': 'https://www.thuisarts.nl/aardbeivlek',
# ...
